# %% [markdown]
# ## Getting the data

# %% [markdown]
# In this Jupyter notebook, I want to keep track of a few things:
# 1. Where we are sourcing our data.
# 2. The method by which we obtain data (e.g. scraping, using an API, etc.)
# 3. Some preliminary data cleaning and organization.

# %% [markdown]
# Recall that we are trying to identify a relationship between the lobbying behavior and the individual stock trades of congresspeople. Let's start with the lobbying data.

# %% [markdown]
# ### Lobbying data

# %% [markdown]
# #### opensecrets.org

# %% [markdown]
# opensecrets.org is a non-profit watchdog organization that tries to keep track of money in politics. I think it is a good first place to look for finding out the different sectors of lobbying, and for determining broad-stroke impressions about money in politics. For instance - it has information on
# 1. Personal financial disclosures of congresspeople and estimates of their net worth.
# 2. Campaign contributions/ fundraising data.
# 3. Political ads by industries, either through 527s (issue advocacy groups) or PACs (often businesses, labor unions, or ideological interests)
# 4. __Domestic and foreign lobbying efforts, in the traditional sense__.
#
# This last one is what we are most interested in, at least for an initial pass.
#
# NB: All the data opensecrets.org has is itself aggregated from different sources. In particular, data on lobbying efforts is all taken from disclosures from the office of the senate - we will look at this source next, as it is likely more granular in nature.

# %% [markdown]
# We will use the CRP API from opensecrets.org to access their data.
# The API is easy to register for here: https://www.opensecrets.org/open-data/api.

# %% [markdown]
# ##### Using the python library

# %% [markdown]
# There is a python client library, due to Rob Remington, "opensecrets-crpapi" which allows us to interface with the CRP API through python. See: https://github.com/robrem/opensecrets-crpapi. This library is, however, 7 years old!
# We can try to use this to download some data.

# %%
pip install opensecrets-crpapi
# Out:
# Requirement already satisfied: opensecrets-crpapi in /Users/rahulkrishna/anaconda3/envs/erdos_sp_2024/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: httplib2 in /Users/rahulkrishna/anaconda3/envs/erdos_sp_2024/lib/python3.11/site-packages (from opensecrets-crpapi) (0.22.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/rahulkrishna/anaconda3/envs/erdos_sp_2024/lib/python3.11/site-packages (from httplib2->opensecrets-crpapi) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from crpapi import CRP
from API_Keys import get_opensecrets_key

crp=CRP(get_opensecrets_key()) #makes a CRP object

object_methods = [method_name for method_name in dir(crp) if callable(getattr(crp, method_name))]
print(dir(crp))
# Out:
# ['BASE_URI', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'apikey', 'candidates', 'committees', 'fetch', 'http', 'indexp', 'orgs']

# %% [markdown]
# It looks like 'candidates', 'committees', 'fetch', 'http', 'indexp', 'orgs' are callable class methods in the library. 'candidates' is documented in the readme - it lets you get basic information on a legislator through their "CID".

# %%
crp.candidates.get('N00007360')
# Out:
# {'@attributes': {'cid': 'N00007360',
#   'firstlast': 'Nancy Pelosi',
#   'lastname': 'Pelosi',
#   'party': 'D',
#   'office': 'CA11',
#   'gender': 'F',
#   'first_elected': '1987',
#   'exit_code': '0',
#   'comments': '',
#   'phone': '202-225-4965',
#   'fax': '202-225-8259',
#   'website': 'http://pelosi.house.gov',
#   'webform': 'http://pelosi.house.gov/contact-me/email-me',
#   'congress_office': '233 Cannon House Office Building',
#   'bioguide_id': 'P000197',
#   'votesmart_id': '26732',
#   'feccandid': 'H8CA05035',
#   'twitter_id': 'NancyPelosi',
#   'youtube_url': 'https://youtube.com/nancypelosi',
#   'facebook_id': 'NancyPelosi',
#   'birthdate': '1940-03-26'}}

# %% [markdown]
# Calling candidates.industries(CID=,year=) will return the industries that have contributed to the candidate until that year.

# %%
crp.candidates.industries('N00007360',"2023")
# Out:
# [{'@attributes': {'industry_code': 'W06',
#    'industry_name': 'Retired',
#    'indivs': '5711313',
#    'pacs': '0',
#    'total': '5711313'}},
#  {'@attributes': {'industry_code': 'H01',
#    'industry_name': 'Health Professionals',
#    'indivs': '361377',
#    'pacs': '183500',
#    'total': '544877'}},
#  {'@attributes': {'industry_code': 'W04',
#    'industry_name': 'Education',
#    'indivs': '521707',
#    'pacs': '0',
#    'total': '521707'}},
#  {'@attributes': {'industry_code': 'F07',
#    'industry_name': 'Securities & Investment',
#    'indivs': '420995',
#    'pacs': '47500',
#    'total': '468495'}},
#  {'@attributes': {'industry_code': 'K01',
#    'industry_name': 'Lawyers/Law Firms',
#    'indivs': '402805',
#    'pacs': '63500',
#    'total': '466305'}},
#  {'@attributes': {'industry_code': 'F10',
#    'industry_name': 'Real Estate',
#    'indivs': '336502',
#    'pacs': '45000',
#    'total': '381502'}},
#  {'@attributes': {'industry_code': 'B02',
#    'industry_name': 'TV/Movies/Music',
#    'indivs': '326385',
#    'pacs': '9000',
#    'total': '335385'}},
#  {'@attributes': {'industry_code': 'W03',
#    'industry_name': 'Civil Servants/Public Officials',
#    'indivs': '194454',
#    'pacs': '0',
#    'total': '194454'}},
#  {'@attributes': {'industry_code': 'B12',
#    'industry_name': 'Electronics Mfg & Equip',
#    'indivs': '153464',
#    'pacs': '24500',
#    'total': '177964'}},
#  {'@attributes': {'industry_code': 'N05',
#    'industry_name': 'Business Services',
#    'indivs': '167542',
#    'pacs': '2500',
#    'total': '170042'}}]

# %%
crp.candidates.summary('N00007360',"2023")
# Out:
# {'cand_name': 'Pelosi, Nancy',
#  'cid': 'N00007360',
#  'cycle': '2024',
#  'state': 'CA',
#  'party': 'D',
#  'chamber': 'H',
#  'first_elected': '1987',
#  'next_election': '2024',
#  'total': '4903098.11',
#  'spent': '4881103.22',
#  'cash_on_hand': '3615723.65',
#  'debt': '0',
#  'origin': 'OpenSecrets',
#  'source': 'https://www.opensecrets.org/members-of-congress/summary?cid=N00007360&cycle=2024',
#  'last_updated': '02/14/2024'}

# %% [markdown]
# Certainly the Python library has limited functionality - we should interface with the opensecrets API more directly.

# %% [markdown]
# ##### Using the CRP API directly

# %% [markdown]
# We do this using the requests package. The CRP API is well documented here: https://www.opensecrets.org/open-data/api-documentation.

# %%
from requests.auth import HTTPBasicAuth
import requests
import json
from time import sleep

# %%
auth= HTTPBasicAuth('apikey', get_opensecrets_key()) # Creates an authorization object that can be fed into requests when the API key is needed. Unfortunately, I don't know how to pass this object to actually feed the API my key.
CRP_url= "https://opensecrets.org/api/"
CRP_params ={}

# %% [markdown]
# Now, let's make some calls.

# %% [markdown]
# ### Lobbying disclosures from the Office of the Senate (LDA)

# %% [markdown]
# Since lobbying data from opensecrets seems a bit coarse, we can try looking at the API offered by the Office of the Senate.

# %% [markdown]
# Let's run through and grab the filings for lobbyists from various years. We first establish some basics.

# %%
from API_Keys import get_LDA_key

LDA_url="https://lda.senate.gov/api/v1/"
LDA_headers={"Authorization":"Token "+get_LDA_key()}

def ceil(a,b):
    return -(-a//b)

# %% [markdown]
# The ceiling division function defined above will be useful in determining the total number of pages our search provided (there are 25 entries available on each page).

# %% [markdown]
# We now grab all filings for 2024, saving them as jsons. There are 558 (visible below in the expression filings.json(["count"]) - this is the same when filings is pointing at any of the pages k).

# %%
i=0
LDA_params = {"method":"listFilings","filing_year": str(2024-i)}
filings=requests.get(LDA_url+"filings/", params=LDA_params, headers=LDA_headers)
m=ceil(filings.json()["count"],25)
for k in range(m):
    LDA_params = {"method":"listFilings","filing_year": str(2024-i),"page":str(k+1)}
    filings=requests.get(LDA_url+"filings/", params=LDA_params, headers=LDA_headers)
    with open("./LDA_data/Filings_2024/filings_"+str(2024-i)+"_p"+str(k+1)+".json", "w") as outfile:
        json.dump(filings.json(), outfile)
    sleep(2)

# %%
filings.json()["count"]
# Out:
# 558

# %% [markdown]
# We import numpy and pandas as usual, so we can look at these files in DataFrame format.

# %%
import pandas as pd
import numpy as np
# Out:
# /var/folders/ln/nt00cb4n18752q_3n96dk_2c0000gn/T/ipykernel_4651/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
filings_2024=pd.DataFrame()
for k in range(23): #23 was our old m 
    with open("LDA_data/Filings_2024/filings_2024_p"+str(k+1)+".json") as file:
        data = json.load(file)["results"]
        filings_2024=pd.concat([filings_2024,pd.DataFrame(data)], ignore_index=True)

filings_2024
# Out:
#                                                    url  \
# 0    https://lda.senate.gov/api/v1/filings/7866327b...
# 1    https://lda.senate.gov/api/v1/filings/295a9fd5...
# 2    https://lda.senate.gov/api/v1/filings/467e4a97...
# 3    https://lda.senate.gov/api/v1/filings/d4c934f7...
# 4    https://lda.senate.gov/api/v1/filings/f32a7add...
# ..                                                 ...
# 553  https://lda.senate.gov/api/v1/filings/4fdfde6f...
# 554  https://lda.senate.gov/api/v1/filings/ffad79e3...
# 555  https://lda.senate.gov/api/v1/filings/88d130aa...
# 556  https://lda.senate.gov/api/v1/filings/d9368a0d...
# 557  https://lda.senate.gov/api/v1/filings/1aea544e...
#
#                               filing_uuid filing_type  \
# 0    7866327b-c892-4430-b9f0-1f0f679c58c6          RR
# 1    295a9fd5-5775-4a38-b8d3-8897973ab6cd          RR
# 2    467e4a97-6351-4902-8ffa-dd51632e156b          Q1
# 3    d4c934f7-dab7-4600-95dc-e0f1ff05a8a7          Q1
# 4    f32a7add-ee52-4ac8-b28a-7720917ae371          RR
# ..                                    ...         ...
# 553  4fdfde6f-8080-4564-97b9-b774d0eae1d2          RR
# 554  ffad79e3-a11f-4f04-8d11-b5122ee26ee0          RR
# 555  88d130aa-3358-4efa-b853-f12cecedec3f          RR
# 556  d9368a0d-2771-4ab9-b0b3-800861704526          RA
# 557  1aea544e-6c9d-4d7d-b2df-6ca5c71dc12c          Q1
#
#           filing_type_display  filing_year  filing_period  \
# 0                Registration         2024  first_quarter
# 1                Registration         2024  first_quarter
# 2        1st Quarter - Report         2024  first_quarter
# 3        1st Quarter - Report         2024  first_quarter
# 4                Registration         2024  first_quarter
# ..                        ...          ...            ...
# 553              Registration         2024  first_quarter
# 554              Registration         2024  first_quarter
# 555              Registration         2024  first_quarter
# 556  Registration - Amendment         2024  first_quarter
# 557      1st Quarter - Report         2024  first_quarter
#
#             filing_period_display  \
# 0    1st Quarter (Jan 1 - Mar 31)
# 1    1st Quarter (Jan 1 - Mar 31)
# 2    1st Quarter (Jan 1 - Mar 31)
# 3    1st Quarter (Jan 1 - Mar 31)
# 4    1st Quarter (Jan 1 - Mar 31)
# ..                            ...
# 553  1st Quarter (Jan 1 - Mar 31)
# 554  1st Quarter (Jan 1 - Mar 31)
# 555  1st Quarter (Jan 1 - Mar 31)
# 556  1st Quarter (Jan 1 - Mar 31)
# 557  1st Quarter (Jan 1 - Mar 31)
#
#                                    filing_document_url  \
# 0    https://lda.senate.gov/filings/public/filing/7...
# 1    https://lda.senate.gov/filings/public/filing/2...
# 2    https://lda.senate.gov/filings/public/filing/4...
# 3    https://lda.senate.gov/filings/public/filing/d...
# 4    https://lda.senate.gov/filings/public/filing/f...
# ..                                                 ...
# 553  https://lda.senate.gov/filings/public/filing/4...
# 554  https://lda.senate.gov/filings/public/filing/f...
# 555  https://lda.senate.gov/filings/public/filing/8...
# 556  https://lda.senate.gov/filings/public/filing/d...
# 557  https://lda.senate.gov/filings/public/filing/1...
#
#     filing_document_content_type    income  ... registrant_different_address  \
# 0                      text/html      None  ...                         None
# 1                      text/html      None  ...                         None
# 2                      text/html  30000.00  ...                        False
# 3                      text/html  15000.00  ...                        False
# 4                      text/html      None  ...                         None
# ..                           ...       ...  ...                          ...
# 553                    text/html      None  ...                         None
# 554                    text/html      None  ...                         None
# 555                    text/html      None  ...                         None
# 556                    text/html      None  ...                         None
# 557                    text/html  40000.00  ...                        False
#
#     registrant_city registrant_state registrant_zip  \
# 0        WASHINGTON               DC          20036
# 1        Washington               DC          20005
# 2        Washington               DC          20002
# 3        Washington               DC          20002
# 4        Washington               DC          20006
# ..              ...              ...            ...
# 553      Washington               DC          20006
# 554      Alexandria               VA          22301
# 555      Washington               DC          20001
# 556       ROCKVILLE               MD          20850
# 557    Spotsylvania               VA          22551
#
#                                             registrant  \
# 0    {'id': 35707, 'url': 'https://lda.senate.gov/a...
# 1    {'id': 321555, 'url': 'https://lda.senate.gov/...
# 2    {'id': 401107792, 'url': 'https://lda.senate.g...
# 3    {'id': 401107792, 'url': 'https://lda.senate.g...
# 4    {'id': 401103955, 'url': 'https://lda.senate.g...
# ..                                                 ...
# 553  {'id': 24486, 'url': 'https://lda.senate.gov/a...
# 554  {'id': 401105227, 'url': 'https://lda.senate.g...
# 555  {'id': 400711132, 'url': 'https://lda.senate.g...
# 556  {'id': 71952, 'url': 'https://lda.senate.gov/a...
# 557  {'id': 401105615, 'url': 'https://lda.senate.g...
#
#                                                 client  \
# 0    {'id': 58116, 'url': 'https://lda.senate.gov/a...
# 1    {'id': 58117, 'url': 'https://lda.senate.gov/a...
# 2    {'id': 56764, 'url': 'https://lda.senate.gov/a...
# 3    {'id': 57213, 'url': 'https://lda.senate.gov/a...
# 4    {'id': 58125, 'url': 'https://lda.senate.gov/a...
# ..                                                 ...
# 553  {'id': 58919, 'url': 'https://lda.senate.gov/a...
# 554  {'id': 58920, 'url': 'https://lda.senate.gov/a...
# 555  {'id': 58921, 'url': 'https://lda.senate.gov/a...
# 556  {'id': 165520, 'url': 'https://lda.senate.gov/...
# 557  {'id': 205777, 'url': 'https://lda.senate.gov/...
#
#                                    lobbying_activities conviction_disclosures  \
# 0    [{'general_issue_code': 'DIS', 'general_issue_...                     []
# 1    [{'general_issue_code': 'NAT', 'general_issue_...                     []
# 2    [{'general_issue_code': 'TEC', 'general_issue_...                     []
# 3    [{'general_issue_code': 'INT', 'general_issue_...                     []
# 4    [{'general_issue_code': 'GOV', 'general_issue_...                     []
# ..                                                 ...                    ...
# 553  [{'general_issue_code': 'AUT', 'general_issue_...                     []
# 554  [{'general_issue_code': 'DEF', 'general_issue_...                     []
# 555  [{'general_issue_code': 'FUE', 'general_issue_...                     []
# 556  [{'general_issue_code': 'HCR', 'general_issue_...                     []
# 557  [{'general_issue_code': 'DEF', 'general_issue_...                     []
#
#     foreign_entities affiliated_organizations
# 0                 []                       []
# 1                 []                       []
# 2                 []                       []
# 3                 []                       []
# 4                 []                       []
# ..               ...                      ...
# 553               []                       []
# 554               []                       []
# 555               []                       []
# 556               []                       []
# 557               []                       []
#
# [558 rows x 30 columns]

# %% [markdown]
# Let me save this as one file for future access.

# %%
filings_2024.to_json('./LDA_data/Filings_2024/filings_2024_total.json', orient='records', lines=True)

# %% [markdown]
# Looks good. Now let's grab the 2023 data - there should be a lot more compared to the 2024 data, given that we are only in February 2024 right now.

# %%
LDA_params = {"method":"listFilings","filing_year": str(2024-1)}
filings=requests.get(LDA_url+"filings/", params=LDA_params, headers=LDA_headers)
m=ceil(filings.json()["count"],25)

# %%
print(filings.json()["count"],m)
# Out:
# 93683 3748

# %% [markdown]
# Oh dear, there are 93,683 filings for 2023. That means we expect 3,748 files when we download.

# %%
i=1
LDA_params = {"method":"listFilings","filing_year": str(2024-i)}
filings=requests.get(LDA_url+"filings/", params=LDA_params, headers=LDA_headers)
m=ceil(filings.json()["count"],25)
for k in range(m):
    LDA_params = {"method":"listFilings","filing_year": str(2024-i),"page":str(k+1)}
    filings=requests.get(LDA_url+"filings/", params=LDA_params, headers=LDA_headers)
    with open("./LDA_data/Filings_2023/filings_"+str(2024-i)+"_p"+str(k+1)+".json", "w") as outfile:
        json.dump(filings.json(), outfile)

# %% [markdown]
# It took a little over 2 hours of this code running to download the 2023 filings (but it did it!). In the future, we may wish to parallelize the procedure a bit. In the above we were making roughly 28 calls a minute, while the API throttles us at 200 calls a minute. So we could easily speed up things by a factor of 6 or 7 by breaking up and running many calls simultaneously.

# %% [markdown]
# In any case, we definitely don't want to make a pandas dataframe with all 93,638 rows. Instead, let's first work with a random selection of 50 of the 3,749 files.

# %%
np.random.seed(691)
ind=list(np.random.randint(1,3749,50)) #choosing a list of 50 random files to pull data on
filings_2023=pd.DataFrame()
for k in ind:
    with open("LDA_data/Filings_2023/filings_2023_p"+str(k+1)+".json") as file:
        data = json.load(file)["results"]
        filings_2023=pd.concat([filings_2023,pd.DataFrame(data)], ignore_index=True)

# %%
filings_2023.keys()
# Out:
# Index(['url', 'filing_uuid', 'filing_type', 'filing_type_display',
#        'filing_year', 'filing_period', 'filing_period_display',
#        'filing_document_url', 'filing_document_content_type', 'income',
#        'expenses', 'expenses_method', 'expenses_method_display',
#        'posted_by_name', 'dt_posted', 'termination_date', 'registrant_country',
#        'registrant_ppb_country', 'registrant_address_1',
#        'registrant_address_2', 'registrant_different_address',
#        'registrant_city', 'registrant_state', 'registrant_zip', 'registrant',
#        'client', 'lobbying_activities', 'conviction_disclosures',
#        'foreign_entities', 'affiliated_organizations'],
#       dtype='object')

# %%
filings_2023["expenses"]=filings_2023["expenses"].fillna(value=0).astype(float)
filings_2023["income"]=filings_2023["income"].fillna(value=0).astype(float)
active_filings_2023=filings_2023.loc[(filings_2023["expenses"]!= 0) | (filings_2023["income"]!=0)]

# %%
active_filings_2023
# Out:
#                                                     url  \
# 0     https://lda.senate.gov/api/v1/filings/6a18095c...
# 1     https://lda.senate.gov/api/v1/filings/c1cbd217...
# 3     https://lda.senate.gov/api/v1/filings/2c38982d...
# 4     https://lda.senate.gov/api/v1/filings/7e37cd52...
# 5     https://lda.senate.gov/api/v1/filings/5c7d241c...
# ...                                                 ...
# 1243  https://lda.senate.gov/api/v1/filings/0cadb69a...
# 1244  https://lda.senate.gov/api/v1/filings/d80df023...
# 1245  https://lda.senate.gov/api/v1/filings/48d168b4...
# 1247  https://lda.senate.gov/api/v1/filings/09aecc6b...
# 1249  https://lda.senate.gov/api/v1/filings/97580611...
#
#                                filing_uuid filing_type   filing_type_display  \
# 0     6a18095c-96b3-498e-8563-9c92e73c4f57          Q4  4th Quarter - Report
# 1     c1cbd217-8f0e-49c4-a743-c9b6a6b67021          Q4  4th Quarter - Report
# 3     2c38982d-2d13-4609-a979-9e06ed26138c          Q4  4th Quarter - Report
# 4     7e37cd52-a2c6-424e-abe7-7edfdde38e5f          Q4  4th Quarter - Report
# 5     5c7d241c-ada1-4351-b825-c6143cb0fe1a          Q4  4th Quarter - Report
# ...                                    ...         ...                   ...
# 1243  0cadb69a-b11e-4d2c-8254-de94f4ebca62          Q1  1st Quarter - Report
# 1244  d80df023-60d9-4b95-ab2c-db53a742eb9f          Q1  1st Quarter - Report
# 1245  48d168b4-60ff-439d-9100-53977cffe2dc          Q1  1st Quarter - Report
# 1247  09aecc6b-c04b-4e20-8a34-c03b3c06d19f          Q1  1st Quarter - Report
# 1249  97580611-4aab-4ce2-bb0b-24974ed66593          Q1  1st Quarter - Report
#
#       filing_year   filing_period         filing_period_display  \
# 0            2023  fourth_quarter  4th Quarter (Oct 1 - Dec 31)
# 1            2023  fourth_quarter  4th Quarter (Oct 1 - Dec 31)
# 3            2023  fourth_quarter  4th Quarter (Oct 1 - Dec 31)
# 4            2023  fourth_quarter  4th Quarter (Oct 1 - Dec 31)
# 5            2023  fourth_quarter  4th Quarter (Oct 1 - Dec 31)
# ...           ...             ...                           ...
# 1243         2023   first_quarter  1st Quarter (Jan 1 - Mar 31)
# 1244         2023   first_quarter  1st Quarter (Jan 1 - Mar 31)
# 1245         2023   first_quarter  1st Quarter (Jan 1 - Mar 31)
# 1247         2023   first_quarter  1st Quarter (Jan 1 - Mar 31)
# 1249         2023   first_quarter  1st Quarter (Jan 1 - Mar 31)
#
#                                     filing_document_url  \
# 0     https://lda.senate.gov/filings/public/filing/6...
# 1     https://lda.senate.gov/filings/public/filing/c...
# 3     https://lda.senate.gov/filings/public/filing/2...
# 4     https://lda.senate.gov/filings/public/filing/7...
# 5     https://lda.senate.gov/filings/public/filing/5...
# ...                                                 ...
# 1243  https://lda.senate.gov/filings/public/filing/0...
# 1244  https://lda.senate.gov/filings/public/filing/d...
# 1245  https://lda.senate.gov/filings/public/filing/4...
# 1247  https://lda.senate.gov/filings/public/filing/0...
# 1249  https://lda.senate.gov/filings/public/filing/9...
#
#      filing_document_content_type   income  ...  registrant_different_address  \
# 0                       text/html  50000.0  ...                         False
# 1                       text/html  25000.0  ...                         False
# 3                       text/html      0.0  ...                         False
# 4                       text/html  40000.0  ...                         False
# 5                       text/html  30000.0  ...                         False
# ...                           ...      ...  ...                           ...
# 1243                    text/html      0.0  ...                         False
# 1244                    text/html  30000.0  ...                         False
# 1245                    text/html  20000.0  ...                         False
# 1247                    text/html  30000.0  ...                         False
# 1249                    text/html      0.0  ...                         False
#
#      registrant_city registrant_state registrant_zip  \
# 0         Washington               DC          20036
# 1         Washington               DC          20036
# 3       Philadelphia               PA          19103
# 4         Washington               DC          20003
# 5         Washington               DC          20003
# ...              ...              ...            ...
# 1243          Mclean               VA          22102
# 1244     Rocky River               OH          44116
# 1245       Annapolis               MD          21403
# 1247      WASHINGTON               DC          20005
# 1249       ARLINGTON               VA          22202
#
#                                              registrant  \
# 0     {'id': 5131, 'url': 'https://lda.senate.gov/ap...
# 1     {'id': 400944730, 'url': 'https://lda.senate.g...
# 3     {'id': 17660, 'url': 'https://lda.senate.gov/a...
# 4     {'id': 400797392, 'url': 'https://lda.senate.g...
# 5     {'id': 400534596, 'url': 'https://lda.senate.g...
# ...                                                 ...
# 1243  {'id': 401105287, 'url': 'https://lda.senate.g...
# 1244  {'id': 401103348, 'url': 'https://lda.senate.g...
# 1245  {'id': 314498, 'url': 'https://lda.senate.gov/...
# 1247  {'id': 65191, 'url': 'https://lda.senate.gov/a...
# 1249  {'id': 57338, 'url': 'https://lda.senate.gov/a...
#
#                                                  client  \
# 0     {'id': 105291, 'url': 'https://lda.senate.gov/...
# 1     {'id': 196357, 'url': 'https://lda.senate.gov/...
# 3     {'id': 123219, 'url': 'https://lda.senate.gov/...
# 4     {'id': 207183, 'url': 'https://lda.senate.gov/...
# 5     {'id': 55152, 'url': 'https://lda.senate.gov/a...
# ...                                                 ...
# 1243  {'id': 203500, 'url': 'https://lda.senate.gov/...
# 1244  {'id': 198635, 'url': 'https://lda.senate.gov/...
# 1245  {'id': 184996, 'url': 'https://lda.senate.gov/...
# 1247  {'id': 54478, 'url': 'https://lda.senate.gov/a...
# 1249  {'id': 159975, 'url': 'https://lda.senate.gov/...
#
#                                     lobbying_activities  \
# 0     [{'general_issue_code': 'FIN', 'general_issue_...
# 1     [{'general_issue_code': 'ENG', 'general_issue_...
# 3     [{'general_issue_code': 'ROD', 'general_issue_...
# 4     [{'general_issue_code': 'FIN', 'general_issue_...
# 5     [{'general_issue_code': 'MAN', 'general_issue_...
# ...                                                 ...
# 1243  [{'general_issue_code': 'AER', 'general_issue_...
# 1244  [{'general_issue_code': 'BUD', 'general_issue_...
# 1245  [{'general_issue_code': 'ENG', 'general_issue_...
# 1247  [{'general_issue_code': 'MMM', 'general_issue_...
# 1249  [{'general_issue_code': 'CSP', 'general_issue_...
#
#      conviction_disclosures foreign_entities affiliated_organizations
# 0                        []               []                       []
# 1                        []               []                       []
# 3                        []               []                       []
# 4                        []               []                       []
# 5                        []               []                       []
# ...                     ...              ...                      ...
# 1243                     []               []                       []
# 1244                     []               []                       []
# 1245                     []               []                       []
# 1247                     []               []                       []
# 1249                     []               []                       []
#
# [932 rows x 30 columns]
